# %%
#q.1
"""When creating custom exceptions in a programming language, it is a good
 practice to derive them from the built-in Exception class or a subclass of
Exceptio.
reason why exception class is recomended:
1.compatablity with exception handling
2.consistent error handling patterns.
3.provide addational feature and method."""
# Out:
# 'When creating custom exceptions in a programming language, it is a good\n practice to derive them from the built-in Exception class or a subclass of\nExceptio.\nreason why exception class is recomended:\n1.compatablity with exception handling\n2.consistent error handling patterns.\n3.provide addational feature and method.'

# %%
#q.2
def print_exception_hierarchy(exception_class, indentation=0):
    print(' ' * indentation + f"{exception_class.__name__}")
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indentation + 2)

if __name__ == "__main__":
    print_exception_hierarchy(Exception)
# Out:
# Exception
#   TypeError
#     MultipartConversionError
#     FloatOperation
#     UFuncTypeError
#       UFuncTypeError
#       UFuncTypeError
#       UFuncTypeError
#         UFuncTypeError
#         UFuncTypeError
#     ConversionError
#   StopAsyncIteration
#   StopIteration
#   ImportError
#     ModuleNotFoundError
#       PackageNotFoundError
#     ZipImportError
#   OSError
#     ConnectionError
#       BrokenPipeError
#       ConnectionAbortedError
#       ConnectionRefusedError
#       ConnectionResetError
#         RemoteDisconnected
#     BlockingIOError
#     ChildProcessError
#     FileExistsError
#     FileNotFoundError
#       ExecutableNotFoundError
#     IsADirectoryError
#     NotADirectoryError
#     InterruptedError
#       InterruptedSystemCall
#     PermissionError
#     ProcessLookupError
#     TimeoutError
#     UnsupportedOperation
#     itimer_error
#     Error
#       SameFileError
#     SpecialFileError
#     ExecError
#     ReadError
#     herror
# ...

# %%
#q.3
"""The ArithmeticError class in Python is a base class for exceptions that occur during arithmetic operations. Two common subclasses of ArithmeticError are ZeroDivisionError and OverflowError.
 Let's explore these two errors with"""

 #1.Zero Division error:
try:
  result=5/0
except ZeroDivisionError as e:
  print(f"Error:{e}\n")

#2.overflow error:
import sys
try:
  result=sys.maxsize+1
except OverflowError as e:
  print(f"error:{e}")
# Out:
# Error:division by zero

# %%
#q.4
"""The LookupError class in Python is a base class for exceptions that occur when a key or index is not found. Two common subclasses of LookupError are KeyError and IndexError.
  these two errors with examples:"""
my_list = [1, 2, 3, 4, 5]

try:
    element = my_list[10]
except IndexError as e:
    print(f"Error: {e}")
# Out:
# Error: list index out of range

# %%
#q.6
"""ImportError is a general exception that is raised when an import statement
 encounters an issue."""
try:
    import non_existent_module
except ImportError as e:
    print(f"Error: {e}")
# Out:
# Error: No module named 'non_existent_module'

# %%
#q.7
"""
1.just always specify exception
2.while handling with the error print always proper message
3.always try to log your error
4.always avoid to write multiple exception
5.document all the error
6.clean up all the resources"""
# Out:
# '\n1.just always specify exception\n2.while handling with the error print always proper message\n3.always try to log your error\n4.always avoid to write multiple exception\n5.document all the error\n6.clean up all the resources'
